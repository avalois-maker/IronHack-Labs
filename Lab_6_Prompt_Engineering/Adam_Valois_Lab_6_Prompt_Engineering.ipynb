# %%
import os
from openai import OpenAI
import json
from collections import Counter
import time
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Initialize OpenAI client
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# Set default model
MODEL = "gpt-4o-mini"

print("✅ Setup complete! OpenAI client initialized.")
# Out:
# ✅ Setup complete! OpenAI client initialized.

# %%
# Define a safe `call_openai` helper so the notebook won't error.
# If you have an API key it will call the real API; otherwise this
# fallback mock returns simple sentiment labels for testing.
try:
	def call_openai(prompt, system_message="You are a helpful assistant.", temperature=0.7, max_tokens=None, seed=None):
		# If the OpenAI client is available and API key present, call the API
		if 'client' in globals() and os.environ.get("OPENAI_API_KEY"):
			params = {
				"model": MODEL,
				"messages": [
					{"role": "system", "content": system_message},
					{"role": "user", "content": prompt}
				],
				"temperature": temperature
			}
			if max_tokens is not None:
				params["max_tokens"] = max_tokens
			if seed is not None:
				params["seed"] = seed
			resp = client.chat.completions.create(**params)
			return resp.choices[0].message.content
		# Fallback mock for local testing without API key
		text = prompt.lower()
		if any(w in text for w in ["love", "great", "excellent", "amazing"]):
			return "Positive"
		if any(w in text for w in ["hate", "terrible", "awful"]):
			return "Negative"
		return "Neutral"
except Exception:
	# Ensure notebook doesn't crash if something unexpected happens during definition
	def call_openai(prompt, **_):
		text = prompt.lower()
		if any(w in text for w in ["love", "great"]):
			return "Positive"
		if any(w in text for w in ["hate", "terrible"]):
			return "Negative"
		return "Neutral"

print("✅ call_openai helper defined (real API if configured, otherwise mocked).")
# Out:
# ✅ call_openai helper defined (real API if configured, otherwise mocked).

# %%
# Initial simple prompt for sentiment analysis
sentiment_prompt_v1 = """
Classify this customer message: "I love this product! It's exactly what I needed."
"""

# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(sentiment_prompt_v1)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# The customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------
# Run #2 result:
# The customer message can be classified as **positive feedback** or **customer satisfaction**.
# ----------------------------------------
# Run #3 result:
# This customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------
# Run #4 result:
# This customer message can be classified as **Positive Feedback** or **Customer Satisfaction**.
# ----------------------------------------
# Run #5 result:
# The customer message can be classified as **positive feedback** or **satisfaction**.
# ----------------------------------------
# Run #6 result:
# The customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------
# Run #7 result:
# ...

# %% [markdown]
# ###Result of running 5 times
# Run #1 result:
# This customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------
# Run #2 result:
# This customer message can be classified as **Positive Feedback** or **Customer Satisfaction**.
# ----------------------------------------
# Run #3 result:
# The customer message can be classified as **positive feedback** or **customer satisfaction**.
# ----------------------------------------
# Run #4 result:
# This customer message can be classified as **Positive Feedback** or **Customer Satisfaction**.
# ----------------------------------------
# Run #5 result:
# The customer message can be classified as **Positive Feedback** or **Customer Satisfaction**.

# %% [markdown]
# ###Result of running 15 times
# Run #1 result:
# The customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------
# Run #2 result:
# The customer message can be classified as **positive feedback** or **customer satisfaction**.
# ----------------------------------------
# Run #3 result:
# This customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------
# Run #4 result:
# This customer message can be classified as **Positive Feedback** or **Customer Satisfaction**.
# ----------------------------------------
# Run #5 result:
# The customer message can be classified as **positive feedback** or **satisfaction**.
# ----------------------------------------
# Run #6 result:
# The customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------
# Run #7 result:
# The customer message can be classified as "Positive Feedback" or "Satisfaction."
# ----------------------------------------
# Run #8 result:
# The customer message can be classified as **positive feedback** or **satisfaction**.
# ----------------------------------------
# Run #9 result:
# The customer message can be classified as **positive feedback** or **customer satisfaction**.
# ----------------------------------------
# Run #10 result:
# This customer message can be classified as **Positive Feedback** or **Customer Satisfaction**.
# ----------------------------------------
# Run #11 result:
# This customer message can be classified as "Positive Feedback" or "Satisfaction."
# ----------------------------------------
# Run #12 result:
# The customer message can be classified as **positive feedback** or **customer satisfaction**.
# ----------------------------------------
# Run #13 result:
# The customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------
# Run #14 result:
# This customer message can be classified as **positive feedback** or **customer satisfaction**.
# ----------------------------------------
# Run #15 result:
# This customer message can be classified as "Positive Feedback" or "Customer Satisfaction."
# ----------------------------------------

# %%
# Initial simple prompt for product description
product_prompt_v1 = """
Create a product description for a wireless mouse that costs $29.99.
"""

# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(product_prompt_v1)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# **Product Description: Wireless Precision Mouse - $29.99**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for ultimate comfort, efficiency, and style. Priced at just $29.99, this sleek and modern mouse is the perfect companion for both work and play.
#
# **Key Features:**
#
# - **Seamless Wireless Connection:** Enjoy the freedom of movement with a reliable 2.4GHz wireless connection. Say goodbye to tangled cords and hello to a clutter-free workspace!
#
# - **Ergonomic Design:** Crafted for comfort, our mouse fits perfectly in your hand, reducing strain during long hours of use. The contoured shape ensures a natural grip, making it ideal for both left and right-handed users.
#
# - **High Precision Tracking:** Equipped with advanced optical sensor technology, our mouse delivers precise tracking on various surfaces, ensuring smooth navigation and accuracy whether you're browsing, working on projects, or gaming.
#
# ...

# %% [markdown]
# ###Result of running 5 times
# Run #1 result:
# **Product Description: Wireless Comfort Pro Mouse - $29.99**
#
# Experience the freedom of seamless navigation with our Wireless Comfort Pro Mouse, designed for efficiency and style. Priced at just $29.99, this sleek and ergonomic mouse is perfect for both home and office use, making it an essential tool for anyone who values comfort and functionality.
#
# **Key Features:**
#
# - **Ergonomic Design:** The Wireless Comfort Pro Mouse fits perfectly in your hand, reducing strain during long hours of use. Its contoured shape ensures a natural grip, allowing for effortless navigation.
#
# - **2.4GHz Wireless Technology:** Enjoy a stable and reliable connection with our advanced 2.4GHz wireless technology. Say goodbye to tangled cords and enjoy the freedom to move around your workspace.
#
# - **Long Battery Life:** Designed for efficiency, this mouse boasts an impressive battery life, allowing you to work uninterrupted for months on a single set of batteries. Plus, the energy-saving mode ensures it’s always ready when you are.
#
# - **Adjustable DPI Settings:** Customize your cursor sensitivity with adjustable DPI settings. Switch between 800 and 1600 DPI to suit your speed and precision needs, whether you're browsing the web or tackling detailed design projects.
#
# - **Plug and Play Simplicity:** No software installation required! Just plug in the USB receiver and you’re ready to go. Compatible with all major operating systems, including Windows, macOS, and Linux.
#
# - **Stylish Aesthetics:** Available in a variety of colors, the Wireless Comfort Pro Mouse adds a touch of personality to your workspace. Choose the color that best matches your style!
#
# Upgrade your workspace with the Wireless Comfort Pro Mouse, where performance meets comfort at an unbeatable price of $29.99. Whether you're a professional, a student, or a casual user, this mouse is designed to enhance your productivity and elevate your computing experience. Order yours today and enjoy the freedom of wireless convenience!
# ----------------------------------------
# Run #2 result:
# **Product Description: Wireless Precision Mouse**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for both productivity and comfort. Priced at just $29.99, this sleek and modern mouse combines advanced technology with ergonomic design to enhance your workflow.
#
# **Key Features:**
#
# - **Wireless Convenience:** Enjoy the freedom of movement without the hassle of tangled cords. Our Bluetooth connectivity ensures a seamless connection to your laptop or desktop, giving you the flexibility to work from anywhere in your workspace.
#
# - **Ergonomic Design:** Crafted with your comfort in mind, the Wireless Precision Mouse fits naturally in your hand, reducing strain during long hours of use. Its contoured shape allows for a comfortable grip, making it perfect for both casual users and professionals alike.
#
# - **Precision Tracking:** Featuring high-precision optical sensors, this mouse delivers smooth and accurate tracking on various surfaces. Whether you’re navigating through documents, browsing the web, or gaming, experience enhanced speed and responsiveness.
#
# - **Long Battery Life:** With an energy-efficient design, the Wireless Precision Mouse boasts a long-lasting battery that keeps you powered up for weeks on a single charge. Plus, the auto-sleep feature helps conserve battery life when not in use.
#
# - **User-Friendly Controls:** Equipped with customizable buttons, you can easily program shortcuts to streamline your tasks and enhance productivity. Whether you need to switch between applications or navigate your favorite websites, it's all at your fingertips.
#
# - **Sleek and Stylish:** Available in a variety of colors, the Wireless Precision Mouse adds a touch of modern elegance to your workspace. Its compact size makes it easy to slip into your bag, perfect for on-the-go use.
#
# Upgrade your setup with the Wireless Precision Mouse today for just $29.99 and experience the perfect blend of style, comfort, and functionality. Make every click count!
# ----------------------------------------
# Run #3 result:
# **Product Description: Wireless Precision Mouse**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for both work and play. Priced at just $29.99, this sleek and stylish accessory combines ergonomic design with cutting-edge technology for ultimate comfort and functionality.
#
# **Key Features:**
#
# - **Wireless Freedom:** Enjoy the convenience of a clutter-free workspace with advanced 2.4GHz wireless technology. Experience seamless connectivity with a reliable range of up to 33 feet, allowing you to move freely without being tethered to your device.
#
# - **Ergonomic Design:** Crafted with your comfort in mind, the Wireless Precision Mouse features a contoured shape that fits perfectly in your hand, reducing strain during long hours of use. The textured grip ensures maximum control and precision, making it ideal for both everyday tasks and intense gaming sessions.
#
# - **High Precision Tracking:** Equipped with a high-precision optical sensor, this mouse delivers exceptional responsiveness and accuracy on a variety of surfaces. Whether you're scrolling through documents or navigating complex graphics, enjoy smooth and precise tracking every time.
#
# - **Long-Lasting Battery Life:** Forget about frequent battery changes! Our Wireless Precision Mouse boasts an energy-efficient design that can last up to 12 months on a single set of batteries, so you can focus on what matters most without interruptions.
#
# - **Plug-and-Play Convenience:** Setting up is a breeze! Simply plug the USB receiver into your computer, and you're ready to go—no software installation required. Compatible with Windows, macOS, and Linux, this mouse is versatile and easy to use across multiple devices.
#
# - **Sleek and Portable:** With its compact design, this mouse is the perfect companion for your laptop. Slip it into your bag and take it anywhere—whether you're heading to the office or working from a café.
#
# Upgrade your workspace with the Wireless Precision Mouse. Combining style, comfort, and performance, it’s the perfect tool for anyone looking to enhance their productivity. Get yours today for only $29.99 and experience the difference!
# ----------------------------------------
# Run #4 result:
# **Product Description: Wireless Comfort Mouse**
#
# Elevate your computing experience with our Wireless Comfort Mouse, designed for seamless navigation and effortless control. Priced at just $29.99, this sleek and stylish mouse combines practicality with modern technology, making it the perfect accessory for both work and play.
#
# **Key Features:**
#
# - **Ergonomic Design:** Our Wireless Comfort Mouse is crafted to fit perfectly in your hand, reducing strain and enhancing your productivity. Its lightweight build ensures comfort during extended use, whether you're working at your desk or on the go.
#
# - **Reliable Wireless Connection:** Say goodbye to tangled cords! Equipped with advanced wireless technology, this mouse offers a stable and responsive connection up to 33 feet away, allowing you to move freely without any interruptions.
#
# - **Long-lasting Battery Life:** Enjoy weeks of use on a single set of batteries. The Wireless Comfort Mouse is designed with energy efficiency in mind, so you can focus on your tasks without worrying about frequent battery replacements.
#
# - **Precision Tracking:** Featuring high-precision optical sensors, this mouse provides smooth and accurate tracking on various surfaces. Whether you're using it on a desk, couch, or even a bed, expect flawless performance every time.
#
# - **Customizable Buttons:** Tailor your productivity with programmable buttons that allow you to assign your favorite shortcuts. Switch between applications, navigate web pages, or execute commands with just a click.
#
# - **Universal Compatibility:** Compatible with all major operating systems, including Windows, macOS, and Linux, the Wireless Comfort Mouse is the ideal choice for any user looking to enhance their workflow.
#
# **Why Choose Our Wireless Comfort Mouse?**
#
# At just $29.99, you’re investing in a piece of technology that not only complements your digital lifestyle but also enhances it. Join countless satisfied customers who have made the switch to a more comfortable and efficient way of navigating their devices. Perfect for students, professionals, gamers, and anyone in between!
#
# **Order now and experience the freedom of wireless convenience with our Wireless Comfort Mouse!**
# ----------------------------------------
# Run #5 result:
# **Product Description:**
#
# **Wireless Precision: The Ultimate Wireless Mouse for Every User**
#
# Elevate your computing experience with our sleek and stylish Wireless Mouse, designed for both comfort and functionality. Priced at just $29.99, this mouse combines modern technology with user-friendly features, making it the perfect companion for your laptop or desktop.
#
# **Key Features:**
#
# - **Cutting-Edge Wireless Technology:** Enjoy the freedom of movement without the hassle of tangled cords. Our wireless mouse connects effortlessly via a reliable USB receiver, ensuring a stable connection up to 33 feet away.
#
# - **Ergonomic Design:** Crafted for all-day comfort, the contoured shape fits perfectly in your hand, reducing strain during long hours of use. Ideal for both office work and gaming sessions, this mouse is designed to keep you comfortable and focused.
#
# - **Precision Tracking:** Equipped with a high-precision optical sensor, the Wireless Mouse offers smooth and accurate tracking on a variety of surfaces. Whether you’re navigating spreadsheets or browsing the web, enjoy seamless control with every click.
#
# - **Long Battery Life:** Forget about frequent battery changes! With an energy-efficient design, this mouse boasts an impressive battery life that lasts for months on a single set of batteries, ensuring you stay productive without interruptions.
#
# - **Stylish and Portable:** Available in a range of modern colors, the Wireless Mouse adds a touch of elegance to your workspace. Its lightweight and compact design makes it easy to slip into your bag, making it the perfect travel companion.
#
# **Why Choose Our Wireless Mouse?**
#
# At just $29.99, you’re not only investing in a high-quality product but also in a hassle-free experience. Whether you’re a student, a professional, or a casual user, this wireless mouse is built to enhance your productivity and provide you with the freedom to work from anywhere.
#
# **Upgrade your workspace today with our Wireless Mouse – where comfort meets technology!**
# ----------------------------------------

# %% [markdown]
# ###Result of running 15 times
# Run #1 result:
# **Product Description: Wireless Precision Mouse - $29.99**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for ultimate comfort, efficiency, and style. Priced at just $29.99, this sleek and modern mouse is the perfect companion for both work and play.
#
# **Key Features:**
#
# - **Seamless Wireless Connection:** Enjoy the freedom of movement with a reliable 2.4GHz wireless connection. Say goodbye to tangled cords and hello to a clutter-free workspace!
#
# - **Ergonomic Design:** Crafted for comfort, our mouse fits perfectly in your hand, reducing strain during long hours of use. The contoured shape ensures a natural grip, making it ideal for both left and right-handed users.
#
# - **High Precision Tracking:** Equipped with advanced optical sensor technology, our mouse delivers precise tracking on various surfaces, ensuring smooth navigation and accuracy whether you're browsing, working on projects, or gaming.
#
# - **Long Battery Life:** With an energy-efficient design, the Wireless Precision Mouse extends battery life, allowing you to work longer without the hassle of frequent battery changes. Enjoy up to 12 months of usage on a single AA battery!
#
# - **Plug-and-Play Convenience:** Setting up is a breeze. Simply plug the USB receiver into your computer, and you’re ready to go in seconds—no software installation required!
#
# - **Stylish Color Options:** Choose from a variety of eye-catching colors that match your personal style or office decor, adding a touch of flair to your workspace.
#
# Whether you're tackling daily tasks, enjoying a gaming session, or navigating through presentations, the Wireless Precision Mouse offers the perfect blend of functionality and style. Discover the freedom of wireless technology and enhance your productivity with ease.
#
# **Why Wait?** Upgrade your workspace today for just $29.99 and experience the difference!
# ----------------------------------------
# Run #2 result:
# **Product Description: Wireless Freedom: The Ultra-Comfort Wireless Mouse**
#
# Elevate your computing experience with the Ultra-Comfort Wireless Mouse, designed for both productivity and style. Priced at an affordable $29.99, this sleek and ergonomic mouse offers unparalleled convenience and functionality, making it the perfect companion for your home office, remote work, or on-the-go lifestyle.
#
# **Key Features:**
#
# - **Wireless Connectivity**: Enjoy the freedom of wireless technology with a reliable 2.4GHz connection. Say goodbye to tangled cords and hello to a clutter-free workspace.
#
# - **Ergonomic Design**: Crafted with comfort in mind, the Ultra-Comfort Wireless Mouse features a contoured shape that fits perfectly in your hand, reducing strain during long hours of use.
#
# - **Precision Tracking**: Equipped with advanced optical sensor technology, this mouse provides smooth and accurate tracking on various surfaces, ensuring precise cursor control for all your tasks.
#
# - **Long Battery Life**: Forget about frequent battery changes! The Ultra-Comfort Wireless Mouse boasts an impressive battery life, allowing you to work longer without interruption.
#
# - **Easy Setup**: Plug-and-play functionality makes setup a breeze. Simply insert the USB receiver into your computer’s USB port, and you’re ready to go—no software installation required!
#
# - **Sleek Aesthetic**: Available in a range of stylish colors, the Ultra-Comfort Wireless Mouse complements any workspace, blending modern design with everyday functionality.
#
# - **Customizable Buttons**: Enhance your productivity with programmable buttons that allow you to set shortcuts for your most-used functions, making multitasking a cinch.
#
# Whether you're a student, professional, or casual user, the Ultra-Comfort Wireless Mouse delivers the perfect balance of comfort, performance, and value. Upgrade your setup today for just $29.99 and experience the difference that wireless freedom can make!
# ----------------------------------------
# Run #3 result:
# **Product Description: Wireless Precision Mouse**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for both comfort and efficiency. Priced at just $29.99, this sleek and stylish mouse offers the perfect blend of functionality and modern design.
#
# **Key Features:**
#
# - **Wireless Freedom:** Enjoy the ultimate convenience of a wireless connection with a reliable 2.4GHz technology. Say goodbye to tangled cords and enjoy a clutter-free workspace.
#
# - **Ergonomic Design:** Our mouse is thoughtfully crafted to fit comfortably in your hand, reducing strain during long hours of use. The soft-touch surface provides a premium feel, making it perfect for both work and play.
#
# - **High Precision Tracking:** With adjustable DPI settings (up to 2400 DPI), you can effortlessly switch between high-speed movement for gaming and precision control for graphic design or detailed work.
#
# - **Long Battery Life:** Equipped with an energy-efficient battery, our mouse ensures that you can work uninterrupted for weeks on a single charge. Plus, the auto-sleep feature conserves energy when not in use.
#
# - **Easy Setup:** Plug and play! The included USB receiver makes connecting to your laptop or computer a breeze, with no complicated software required.
#
# - **Versatile Compatibility:** Compatible with Windows, macOS, and Linux, this mouse is perfect for any user, whether you're at home, in the office, or on the go.
#
# Upgrade your workspace with our Wireless Precision Mouse, where comfort meets innovation. Perfect for professionals, gamers, and anyone who values quality. Grab yours today for just $29.99 and experience the freedom of wireless technology!
# ----------------------------------------
# Run #4 result:
# **Product Description: Wireless Precision Mouse**
#
# Elevate your computing experience with our Wireless Precision Mouse, now available for just $29.99! Designed for comfort and efficiency, this sleek and stylish mouse is perfect for both work and play.
#
# **Key Features:**
#
# - **Wireless Freedom:** Enjoy the convenience of a clutter-free workspace with advanced wireless technology. Say goodbye to tangled cords and hello to seamless connectivity.
#
# - **Ergonomic Design:** Crafted to fit comfortably in your hand, our mouse reduces strain during long hours of use. The smooth contours provide a natural grip, ensuring you stay comfortable while you work or game.
#
# - **High Precision Tracking:** With adjustable DPI settings, you can switch between different sensitivity levels to suit your needs, whether you’re doing intricate design work or navigating through documents.
#
# - **Long-lasting Battery Life:** Equipped with energy-efficient technology, this mouse promises extended usage on a single set of batteries. Focus on your tasks without the constant worry of recharging.
#
# - **Easy Setup:** Plug and play! Simply insert the USB receiver into your computer, and you’re ready to go. No complicated installations or software required.
#
# - **Versatile Compatibility:** Compatible with a wide range of operating systems, including Windows, macOS, and Linux, making it the perfect accessory for any setup.
#
# **Why Choose the Wireless Precision Mouse?**
#
# At just $29.99, this mouse combines style, comfort, and functionality, making it an unbeatable value. Perfect for students, professionals, and gamers alike, it’s the ideal companion for your laptop or desktop. Upgrade your workspace today and experience the difference!
#
# **Order yours now and take the first step towards a more efficient and enjoyable computing experience!**
# ----------------------------------------
# Run #5 result:
# **Product Description: Wireless Precision Mouse**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for comfort, efficiency, and style—all at an unbeatable price of just $29.99!
#
# **Key Features:**
#
# - **Seamless Connectivity:** Say goodbye to tangled cords! Our advanced 2.4GHz wireless technology ensures a stable connection with a range of up to 30 feet, allowing you to work freely from anywhere in the room.
#
# - **Ergonomic Design:** Engineered for comfort, the sleek, contoured shape fits perfectly in your hand, reducing strain during long work sessions. Whether you're at your desk or on the go, enjoy a natural grip that makes every click effortless.
#
# - **High Precision Tracking:** Equipped with a high-performance optical sensor, our Wireless Precision Mouse delivers smooth and accurate tracking on various surfaces, from your desk to your couch. Experience flawless navigation and responsiveness for all your computing tasks.
#
# - **Long Battery Life:** With an energy-efficient design, this mouse lasts for months on a single AA battery (included), so you can focus on what matters most without the hassle of frequent battery changes.
#
# - **Versatile Compatibility:** Compatible with Windows, macOS, and Linux, our Wireless Precision Mouse is perfect for any setup. Whether you’re a gamer, a student, or a professional, it’s designed to meet your needs.
#
# - **Stylish Options:** Available in multiple color options, you can choose a mouse that reflects your personal style and complements your workspace.
#
# **Why Choose Our Wireless Precision Mouse?**
#
# At just $29.99, you get high-quality performance without breaking the bank. Ideal for home, office, or travel, our mouse combines functionality with an elegant design. Upgrade your digital experience today and enjoy the freedom of wireless connectivity!
#
# **Order Now!** Don’t miss out on this fantastic deal. Click the “Add to Cart” button and take the first step toward a more efficient and stylish computing experience!
# ----------------------------------------
# Run #6 result:
# **Product Description: Wireless Precision Mouse**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for both efficiency and comfort. Priced at just $29.99, this sleek and stylish mouse combines cutting-edge technology with ergonomic design, making it the perfect companion for work, play, or on-the-go use.
#
# **Key Features:**
#
# - **Seamless Wireless Connectivity:** Enjoy the freedom of movement with advanced 2.4GHz wireless technology. No more tangled cords—just plug in the USB receiver and you’re ready to go!
#
# - **Ergonomic Design:** Crafted for comfort, the Wireless Precision Mouse fits perfectly in your hand, reducing strain during long hours of use. Its lightweight build and smooth contours make it ideal for daily tasks, whether at your desk or in your lap.
#
# - **High Precision Tracking:** Equipped with a state-of-the-art optical sensor, this mouse offers exceptional accuracy and responsiveness. Navigate effortlessly across various surfaces with precision tracking up to 1600 DPI.
#
# - **Long-lasting Battery Life:** With an energy-efficient design, the Wireless Precision Mouse ensures you stay productive for weeks on a single set of batteries. Plus, the smart sleep mode helps conserve power when not in use.
#
# - **Stylish and Compact:** Available in a range of modern colors, this mouse not only performs well but also looks great on any workspace. Its compact size makes it easy to slip into your laptop bag for travel.
#
# - **User-Friendly Setup:** Simply plug in the USB receiver and start using it instantly—no software installation required! Compatible with most operating systems, including Windows and macOS.
#
# Transform the way you work and play with the Wireless Precision Mouse. Whether you're tackling a project, browsing the web, or gaming, this mouse delivers both style and functionality at an unbeatable price. Upgrade your setup today for just $29.99 and experience the difference!
# ----------------------------------------
# Run #7 result:
# **Product Name: SwiftConnect Wireless Mouse**
#
# **Price: $29.99**
#
# Elevate your computing experience with the SwiftConnect Wireless Mouse, designed for comfort, precision, and style. Whether you’re working from home, studying, or gaming, this sleek mouse offers the perfect blend of performance and convenience.
#
# **Key Features:**
#
# - **Seamless Wireless Connectivity:** Enjoy the freedom of a clutter-free desk with a reliable 2.4GHz wireless connection. The plug-and-play USB receiver ensures quick setup and a stable connection within a 33-foot range.
#
# - **Ergonomic Design:** Crafted with user comfort in mind, the SwiftConnect features an ergonomic shape that fits comfortably in your hand, reducing strain during extended use. The textured grip ensures you maintain control, whether you’re navigating spreadsheets or online adventures.
#
# - **Precision Tracking:** Equipped with a high-precision optical sensor, this mouse delivers smooth and accurate tracking on various surfaces. Switch between DPI settings (800/1200/1600) with a simple click to tailor your sensitivity to your task.
#
# - **Long-lasting Battery Life:** Forget the hassle of frequent battery changes. Our energy-efficient design provides up to 12 months of use on a single AA battery (included), so you can focus on what matters most.
#
# - **Stylish and Versatile:** Available in multiple colors, the SwiftConnect Wireless Mouse not only complements your workspace but also reflects your personal style. Its compact size makes it easy to take on the go, fitting perfectly in your laptop bag.
#
# - **Compatible with Multiple Devices:** Whether you’re using a Windows PC, Mac, or Chromebook, the SwiftConnect works seamlessly across all platforms, making it the perfect companion for all your devices.
#
# **Why Choose SwiftConnect?**
# At just $29.99, the SwiftConnect Wireless Mouse offers outstanding value without compromising on quality. Experience the freedom of wireless technology, the comfort of ergonomic design, and the precision of advanced tracking—all in one stylish package.
#
# Upgrade your setup today with the SwiftConnect Wireless Mouse and enjoy a smoother, more efficient computing experience!
# ----------------------------------------
# Run #8 result:
# **Product Description: Wireless Precision Mouse - $29.99**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for both work and play. Priced at just $29.99, this sleek and ergonomic mouse delivers exceptional performance without breaking the bank.
#
# **Key Features:**
#
# - **Wireless Freedom**: Enjoy the convenience of a wireless connection with a reliable 2.4GHz technology. Say goodbye to tangled cords and experience true mobility as you navigate seamlessly on any surface.
#
# - **Ergonomic Design**: Crafted for comfort, our mouse fits perfectly in your hand, reducing strain during long hours of use. The contoured shape and textured grip ensure you maintain control and accuracy no matter the task at hand.
#
# - **High Precision Tracking**: Equipped with a high-precision optical sensor, this mouse boasts adjustable DPI settings (800/1200/1600), allowing you to customize your sensitivity for gaming, graphic design, or everyday browsing.
#
# - **Long-lasting Battery Life**: Forget about frequent battery changes! With an energy-efficient design, our wireless mouse can last for months on a single AA battery, ensuring you stay productive without interruption.
#
# - **Plug-and-Play Convenience**: Simply plug the USB receiver into your computer, and you’re ready to go! Compatible with Windows, macOS, and Linux, this mouse is the perfect companion for all your devices.
#
# - **Stylish and Portable**: Available in a range of modern colors, the Wireless Precision Mouse not only performs well but also looks great on your desk. Its lightweight design makes it easy to take with you wherever you go.
#
# **Why Choose Our Wireless Precision Mouse?**
#
# Whether you're a professional looking for reliability, a student needing a portable solution, or a gamer seeking precision, this wireless mouse meets all your needs without compromising quality. With a price point of just $29.99, you get exceptional value and functionality in one stylish package.
#
# Upgrade your setup today and enjoy the freedom of wireless navigation with our Wireless Precision Mouse!
# ----------------------------------------
# Run #9 result:
# **Product Description: Wireless Comfort Mouse - $29.99**
#
# Elevate your productivity and comfort with our Wireless Comfort Mouse, designed for both casual users and professionals alike. Priced at just $29.99, this sleek and stylish mouse offers the perfect blend of performance and convenience.
#
# **Key Features:**
#
# - **Wireless Freedom:** Enjoy the liberty of movement without the hassle of cords. The 2.4 GHz wireless technology provides a reliable connection with a range of up to 33 feet, allowing you to work from anywhere in the room.
#
# - **Ergonomic Design:** Crafted with your comfort in mind, the sculpted shape fits perfectly in your hand, reducing strain during long hours of use. The textured grip ensures you maintain control and precision, whether you're working or gaming.
#
# - **High Precision Tracking:** Experience smooth and accurate tracking with the advanced optical sensor. With adjustable DPI settings (800-1600 DPI), you can customize your cursor speed to suit your unique workflow.
#
# - **Long Battery Life:** Forget about frequent battery changes! Our Wireless Comfort Mouse is equipped with an energy-efficient design that offers up to 12 months of battery life on a single AA battery.
#
# - **Plug-and-Play Convenience:** Setting up your mouse is a breeze. Simply plug the USB receiver into your computer, and you’re ready to go—no software installation required!
#
# - **Stylish Colors:** Choose from a range of vibrant colors to match your personal style or workspace aesthetic.
#
# Whether you're working from home, in the office, or on the go, the Wireless Comfort Mouse is your perfect companion for seamless navigation and enhanced efficiency. Upgrade your setup today for just $29.99 and enjoy the freedom of wireless technology!
# ----------------------------------------
# Run #10 result:
# **Product Description: Wireless Precision Mouse - $29.99**
#
# Elevate your computing experience with our Wireless Precision Mouse, designed for seamless functionality and unmatched comfort. Priced at just $29.99, this sleek and stylish mouse offers the perfect blend of performance and affordability.
#
# **Key Features:**
#
# - **Wireless Freedom:** Say goodbye to tangled cords! Our advanced 2.4GHz wireless technology provides a reliable connection with a range of up to 33 feet, allowing you to work or play without restrictions.
#
# - **Ergonomic Design:** Crafted with user comfort in mind, the Wireless Precision Mouse fits snugly in your hand, reducing strain during long hours of use. Its contoured shape and textured grip ensure you maintain control and comfort.
#
# - **High Precision Tracking:** Experience smooth and accurate navigation with our high-precision optical sensor. Whether you’re browsing the web, editing documents, or gaming, our mouse delivers responsive performance on various surfaces.
#
# - **Long Battery Life:** Enjoy extended usage with our energy-efficient design. The Wireless Precision Mouse features an auto-sleep function that conserves battery life, ensuring you stay productive for longer without the hassle of frequent battery changes.
#
# - **Plug and Play Convenience:** Setting up is a breeze! Simply plug the USB receiver into your computer, and you’re ready to go—no software installation required.
#
# - **Stylish and Compact:** Available in a range of modern colors, the Wireless Precision Mouse adds a touch of style to your workspace. Its compact design makes it perfect for on-the-go professionals and students alike.
#
# Upgrade your workspace with the Wireless Precision Mouse—where quality meets affordability. Whether for work, study, or leisure, this mouse is the perfect companion for all your computing needs. Order yours today for just $29.99 and experience the freedom of wireless technology!
# ----------------------------------------
# Run #11 result:
# **Product Description: Wireless Comfort Mouse**
#
# Elevate your productivity with our Wireless Comfort Mouse, designed for seamless performance and ultimate convenience at an unbeatable price of just $29.99. Whether you're working from home, in the office, or on the go, this sleek and ergonomic mouse offers a smooth and responsive experience that adapts to your needs.
#
# **Key Features:**
#
# - **Wireless Freedom:** Enjoy the convenience of a reliable wireless connection with a range of up to 33 feet. Say goodbye to tangled cords and enjoy a clutter-free workspace.
#
# - **Ergonomic Design:** Crafted for comfort, our mouse fits perfectly in your hand, reducing strain during long hours of use. The contoured shape ensures a natural grip, allowing you to work efficiently without discomfort.
#
# - **Precision Tracking:** Equipped with advanced optical technology, this mouse delivers precise tracking on a variety of surfaces, making it perfect for both detailed design work and everyday tasks.
#
# - **Long Battery Life:** With an energy-efficient design, you can rely on our Wireless Comfort Mouse for months without the hassle of frequent battery changes. Plus, it features an easy-to-replace battery compartment for added convenience.
#
# - **Plug & Play Setup:** Enjoy a hassle-free setup with a simple plug-and-play USB receiver. Connect it to your laptop or desktop in seconds and start working right away.
#
# - **Versatile Compatibility:** Compatible with Windows, macOS, and Linux, this mouse is the perfect companion for all your devices.
#
# Upgrade your workspace today with the Wireless Comfort Mouse. Experience the freedom of wireless technology without compromising on comfort or performance. Order now for only $29.99 and take the first step towards a more efficient and enjoyable computing experience!
# ----------------------------------------
# Run #12 result:
# **Product Name: SwiftClick Wireless Mouse**
#
# **Price: $29.99**
#
# **Product Description:**
#
# Elevate your computing experience with the SwiftClick Wireless Mouse, designed for both functionality and style. This sleek and modern mouse is perfect for home, office, or on-the-go use, offering a seamless wireless connection that keeps you untethered and free to move.
#
# **Key Features:**
#
# - **Ergonomic Design:** The SwiftClick features a comfortable, contoured shape that fits perfectly in your hand, reducing strain during long hours of use. Its lightweight design ensures that you can take it anywhere without hassle.
#
# - **Wireless Convenience:** Enjoy the freedom of wireless technology with a reliable 2.4GHz connection. Simply plug in the USB receiver, and you’re ready to go—no software installation required!
#
# - **Precision Tracking:** Equipped with advanced optical sensor technology, the SwiftClick delivers precise tracking on a variety of surfaces, ensuring smooth and accurate navigation whether you're working on a desk, couch, or even your lap.
#
# - **Adjustable DPI Settings:** Tailor your mouse sensitivity with adjustable DPI settings (800/1200/1600), allowing you to switch between precision tasks like graphic design and fast-paced gaming with ease.
#
# - **Long Battery Life:** Powered by a single AA battery (included), the SwiftClick offers an impressive battery life of up to 12 months, ensuring you spend less time worrying about replacements and more time enjoying your work.
#
# - **Stylish Color Options:** Choose from a range of vibrant colors to match your personal style or workspace décor. Whether you prefer classic black, sleek silver, or a pop of color, there’s a SwiftClick for you!
#
# - **Quiet Click Technology:** Work in peace with our quiet click technology, designed to minimize noise while clicking, making it ideal for shared spaces like offices or libraries.
#
# **Why Choose SwiftClick?**
#
# At just $29.99, the SwiftClick Wireless Mouse combines quality, performance, and affordability, making it the perfect accessory for anyone seeking an upgrade to their computing setup. Whether you're a busy professional, a student, or a casual user, this mouse is built to enhance your productivity without breaking the bank.
#
# **Upgrade your mouse game today with the SwiftClick Wireless Mouse—where comfort meets convenience!**
# ----------------------------------------
# Run #13 result:
# **Product Description: Wireless Freedom: Sleek & Stylish Wireless Mouse - $29.99**
#
# Experience the ultimate in convenience and style with our Wireless Freedom Mouse, designed for both productivity and comfort. Priced at just $29.99, this wireless mouse is the perfect addition to any workspace, whether at home or in the office.
#
# **Key Features:**
#
# - **Ergonomic Design:** The Wireless Freedom Mouse features a comfortable, ergonomic shape that fits perfectly in your hand, reducing strain during long hours of use. Its lightweight design allows for effortless maneuverability, making it ideal for both everyday tasks and extended use.
#
# - **Reliable Wireless Connectivity:** Enjoy the freedom of a clutter-free workspace with advanced 2.4GHz wireless technology. Say goodbye to tangled cords and hello to seamless connectivity with a reliable range of up to 33 feet, allowing you to move freely without interruption.
#
# - **Long-lasting Battery Life:** Equipped with energy-efficient technology, this mouse boasts an impressive battery life that lasts for months on a single set of batteries. You’ll spend less time worrying about replacements and more time focusing on what matters.
#
# - **Customizable Buttons:** Tailor your mouse to fit your unique workflow with programmable buttons that allow you to assign functions for quick access to your most-used tools and applications. Boost your productivity with just a click!
#
# - **Stylish Aesthetic:** Available in a range of vibrant colors, the Wireless Freedom Mouse adds a touch of personality to your desk. Its sleek, modern design complements any setup, making it not just a tool, but a stylish accessory.
#
# - **Plug-and-Play Ease:** Setting up your mouse is a breeze—simply plug the USB receiver into your computer, and you’re ready to go! Compatible with Windows, macOS, and Chrome OS, you can use it with almost any device.
#
# Upgrade your computing experience with the Wireless Freedom Mouse. Whether you’re browsing the web, working on a project, or gaming, this mouse will keep you connected and comfortable. Get yours today for only $29.99 and embrace the freedom of wireless technology!
# ----------------------------------------
# Run #14 result:
# **Product Name: SwiftClick Wireless Mouse**
#
# **Price: $29.99**
#
# **Product Description:**
#
# Elevate your computing experience with the SwiftClick Wireless Mouse, the perfect blend of style, comfort, and functionality. Designed for both work and play, this sleek and modern mouse offers a seamless wireless connection, allowing you to navigate your digital world with ease.
#
# **Key Features:**
#
# - **Wireless Freedom:** Enjoy the convenience of a reliable 2.4GHz wireless connection that provides a stable and responsive performance without the clutter of cords. The included USB receiver conveniently stores in the mouse for easy transport.
#
# - **Ergonomic Design:** Crafted for comfort, the SwiftClick features an ergonomic shape that fits naturally in your hand, reducing strain during long hours of use. The textured grip ensures maximum control, making it perfect for gaming, browsing, or productivity tasks.
#
# - **Adjustable DPI Settings:** Tailor your sensitivity with adjustable DPI settings (800, 1200, 1600) to suit your preferences. Whether you need precision for graphic design or speed for gaming, the SwiftClick adapts to your needs effortlessly.
#
# - **Long Battery Life:** Forget about frequent battery changes! The SwiftClick Wireless Mouse is designed for efficiency, providing up to 12 months of battery life on a single AA battery (included). An auto-sleep feature helps conserve power when not in use.
#
# - **Plug-and-Play Convenience:** Get started in seconds! Simply plug in the USB receiver, and the mouse is ready to go. No drivers or software installations are required.
#
# - **Stylish Colors:** Available in a range of eye-catching colors, the SwiftClick allows you to express your personality while complementing your workspace.
#
# Whether you're a student, a professional, or a gamer, the SwiftClick Wireless Mouse is the ultimate tool for enhancing your productivity and enjoyment. Experience the freedom of wireless technology at an unbeatable price of just $29.99. Upgrade your setup today and click your way to success!
# ----------------------------------------
# Run #15 result:
# **Product Description: Wireless Comfort Mouse - $29.99**
#
# Elevate your computing experience with our Wireless Comfort Mouse, designed for seamless navigation and ultimate convenience. Priced at just $29.99, this stylish and ergonomic mouse is perfect for both home and office use.
#
# **Key Features:**
#
# - **Wireless Freedom**: Enjoy the liberty of a clutter-free workspace with our advanced 2.4GHz wireless technology. Say goodbye to tangled cords and hello to effortless movement.
#
# - **Ergonomic Design**: Crafted with comfort in mind, the Wireless Comfort Mouse fits perfectly in your hand, reducing strain during long hours of use. Its sleek contours offer a natural grip, making it ideal for both right and left-handed users.
#
# - **Precision Tracking**: Equipped with a high-precision optical sensor, this mouse provides smooth tracking on various surfaces, ensuring accurate cursor control for all your tasks, whether you're browsing the web, working on spreadsheets, or gaming.
#
# - **Long Battery Life**: Enjoy extended usage with our energy-efficient design. The Wireless Comfort Mouse boasts an impressive battery life, allowing you to work and play longer without the need for constant replacements.
#
# - **Plug-and-Play Simplicity**: Set up is a breeze! Simply plug the USB receiver into your computer, and you’re ready to go—no additional software required.
#
# - **Stylish and Portable**: Available in a range of modern colors, this mouse not only performs well but also adds a touch of style to your tech collection. Its compact design makes it easy to slip into your bag, perfect for on-the-go professionals.
#
# Upgrade to the Wireless Comfort Mouse today and experience the perfect blend of functionality, style, and comfort—all at an unbeatable price of $29.99. Get ready to enhance your productivity and enjoy the freedom of wireless technology!
# ----------------------------------------

# %%
# Initial simple prompt for data extraction
extraction_prompt_v1 = """
Extract information from this customer feedback: "I ordered item #12345 on March 15th. The delivery was fast but the packaging was damaged."
"""
 
# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(extraction_prompt_v1)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# Here are the key pieces of information extracted from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #2 result:
# Here is the extracted information from the customer feedback:
#
# - **Item Number**: 12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #3 result:
# Here is the extracted information from the customer feedback:
#
# - **Item Ordered**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #4 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ...

# %% [markdown]
# ###Result of running 5 times
# Run #1 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #2 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Issue**: Damaged packaging
# ----------------------------------------
# Run #3 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Item**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #4 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #5 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery**: Fast
# - **Issue**: Damaged packaging
# ----------------------------------------

# %% [markdown]
# ###Result running 15 times
# Run #1 result:
# Here are the key pieces of information extracted from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #2 result:
# Here is the extracted information from the customer feedback:
#
# - **Item Number**: 12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #3 result:
# Here is the extracted information from the customer feedback:
#
# - **Item Ordered**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #4 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #5 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number:** 12345
# - **Order Date:** March 15th
# - **Delivery Speed:** Fast
# - **Packaging Condition:** Damaged
# ----------------------------------------
# Run #6 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number:** #12345
# - **Order Date:** March 15th
# - **Delivery Speed:** Fast
# - **Packaging Condition:** Damaged
# ----------------------------------------
# Run #7 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number**: 12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #8 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number:** 12345
# - **Order Date:** March 15th
# - **Delivery Speed:** Fast
# - **Packaging Condition:** Damaged
# ----------------------------------------
# Run #9 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #10 result:
# Customer Feedback Summary:
# - Order Number: #12345
# - Order Date: March 15th
# - Delivery: Fast
# - Issue: Damaged packaging
# ----------------------------------------
# Run #11 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Item Number**: 12345
# - **Order Date**: March 15th
# - **Delivery**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #12 result:
# Here is the extracted information from the customer feedback:
#
# - **Item Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #13 result:
# Here is the extracted information from the customer feedback:
#
# - **Order Number:** 12345
# - **Order Date:** March 15th
# - **Delivery Speed:** Fast
# - **Packaging Condition:** Damaged
# ----------------------------------------
# Run #14 result:
# Here is the extracted information from the customer feedback:
#
# - **Item Number**: #12345
# - **Order Date**: March 15th
# - **Delivery Speed**: Fast
# - **Packaging Condition**: Damaged
# ----------------------------------------
# Run #15 result:
# Here is the extracted information from the customer feedback:
#
# - **Item Number:** #12345
# - **Order Date:** March 15th
# - **Delivery Speed:** Fast
# - **Packaging Condition:** Damaged
# ----------------------------------------

# %%
# Improved Sentiment Analysis Prompt
sentiment_prompt_v2 = """
Classify this customer message using a single word. Choose from the following words "Very Satisfied", "Satisfied", "Unsatisfied", "Very Unsatisfied": "I love this product! It's exactly what I needed."
"""

# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(sentiment_prompt_v2)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# Very Satisfied
# ----------------------------------------
# Run #2 result:
# Very Satisfied
# ----------------------------------------
# Run #3 result:
# Very Satisfied
# ----------------------------------------
# Run #4 result:
# Very Satisfied
# ----------------------------------------
# Run #5 result:
# Very Satisfied
# ----------------------------------------
# Run #6 result:
# Very Satisfied
# ----------------------------------------
# Run #7 result:
# Very Satisfied
# ----------------------------------------
# Run #8 result:
# Very Satisfied
# ----------------------------------------
# Run #9 result:
# Very Satisfied
# ----------------------------------------
# Run #10 result:
# Very Satisfied
# ----------------------------------------
# Run #11 result:
# Very Satisfied
# ----------------------------------------
# Run #12 result:
# Very Satisfied
# ----------------------------------------
# Run #13 result:
# Very Satisfied
# ...

# %%
#Revised prompt for product description
product_prompt_v2 = """
Create a product description for a wireless mouse that costs $29.99. The target audience is a student with a low budget, they would be interested in shape and color options only. Ensure the length is no more than 50 words, do not use bullet points, natural text only with a bold header.
"""

# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(product_prompt_v2)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# **Affordable Wireless Mouse for Students**
#
# Elevate your study sessions with our budget-friendly wireless mouse, available in vibrant colors and a sleek, ergonomic shape. Designed for comfort and style, this mouse is perfect for students seeking functionality without breaking the bank. Choose your favorite color and enhance your workspace today!
# ----------------------------------------
# Run #2 result:
# **Affordable Wireless Mouse for Students**
#
# Discover the perfect companion for your studies with our budget-friendly wireless mouse. Available in a variety of vibrant colors and a sleek, ergonomic shape, it combines style and comfort without breaking the bank. Enhance your productivity and express your personality for just $29.99!
# ----------------------------------------
# Run #3 result:
# **Stay Stylish and Productive with Our Wireless Mouse**
#
# ...

# %%
# Revised prompt for data extraction
extraction_prompt_v2 = """
Extract key information from this customer feedback such as "Item number", "order date." State key details from the message and return a plain text response summary no more than 25 words: "I ordered item #12345 on March 15th. The delivery was fast but the packaging was damaged."
"""
 
# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(extraction_prompt_v2)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# Item number: 12345, Order date: March 15th. Delivery was fast, but packaging was damaged.
# ----------------------------------------
# Run #2 result:
# Item number: 12345, Order date: March 15th. Delivery was fast, but packaging was damaged.
# ----------------------------------------
# Run #3 result:
# Item number: 12345, Order date: March 15th. Delivery was fast, but packaging was damaged.
# ----------------------------------------
# Run #4 result:
# Item number: 12345, Order date: March 15th. Delivery was fast, but packaging was damaged.
# ----------------------------------------
# Run #5 result:
# Item number: 12345, Order date: March 15th. Delivery was fast, but packaging was damaged.
# ----------------------------------------
# Run #6 result:
# Item number: 12345, Order date: March 15th. Delivery was fast, but packaging was damaged.
# ----------------------------------------
# Run #7 result:
# ...

# %%
# Few Shot Sentiment Analysis Prompt
sentiment_prompt_v3 = """
Classify this customer message: "I love this product! It's exactly what I needed."
Example Output: "Very Satisfied"
"""

# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(sentiment_prompt_v3)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# "Very Satisfied"
# ----------------------------------------
# Run #2 result:
# "Very Satisfied"
# ----------------------------------------
# Run #3 result:
# "Very Satisfied"
# ----------------------------------------
# Run #4 result:
# "Very Satisfied"
# ----------------------------------------
# Run #5 result:
# "Very Satisfied"
# ----------------------------------------
# Run #6 result:
# "Very Satisfied"
# ----------------------------------------
# Run #7 result:
# "Very Satisfied"
# ----------------------------------------
# Run #8 result:
# "Very Satisfied"
# ----------------------------------------
# Run #9 result:
# "Very Satisfied"
# ----------------------------------------
# Run #10 result:
# "Very Satisfied"
# ----------------------------------------
# Run #11 result:
# "Very Satisfied"
# ----------------------------------------
# Run #12 result:
# "Very Satisfied"
# ----------------------------------------
# Run #13 result:
# "Very Satisfied"
# ...

# %%
# Chain of thought prompt for data extraction
extraction_prompt_v3 = """
First extract item number, then order date, and finally delivery and packaging: "I ordered item #12345 on March 15th. The delivery was fast but the packaging was damaged."
"""
 
# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(extraction_prompt_v3)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# Item number: 12345
# Order date: March 15th
# Delivery: Fast
# Packaging: Damaged
# ----------------------------------------
# Run #2 result:
# - Item Number: 12345
# - Order Date: March 15th
# - Delivery: Fast
# - Packaging: Damaged
# ----------------------------------------
# Run #3 result:
# Item number: 12345
# Order date: March 15th
# Delivery: fast
# Packaging: damaged
# ----------------------------------------
# Run #4 result:
# - Item number: 12345
# - Order date: March 15th
# - Delivery: fast
# - Packaging: damaged
# ----------------------------------------
# Run #5 result:
# - Item number: #12345
# - Order date: March 15th
# - Delivery: fast
# - Packaging: damaged
# ----------------------------------------
# Run #6 result:
# - Item Number: 12345
# - Order Date: March 15th
# - Delivery: Fast
# - Packaging: Damaged
# ----------------------------------------
# Run #7 result:
# Item number: 12345
# Order date: March 15th
# Delivery: fast
# Packaging: damaged
# ...

# %%
#Structured prompt for product description
product_prompt_v3 = """
Create a product description for a wireless mouse that costs $29.99.
Example Output should include:
1. Target audience as student
2. Length no more than 50 words
3. Example output: "Cheap & chearful, this mouse has everything a student needs at a price they can afford."
"""

# Run the prompt multiple times to compare results
num_runs = 15
results = []
for i in range(num_runs):
	result = call_openai(product_prompt_v3)
	print(f"Run #{i+1} result:")
	print(result)
	print("-"*40)
	results.append(result)
# Out:
# Run #1 result:
# "Affordable and ergonomic, this wireless mouse is perfect for students on the go. With a sleek design and reliable performance, it offers seamless navigation for class notes and projects without breaking the bank. Elevate your study sessions for just $29.99!"
# ----------------------------------------
# Run #2 result:
# "Affordable and efficient, this wireless mouse is perfect for students on the go. With its sleek design and reliable performance, it makes studying and browsing a breeze—all at just $29.99. Elevate your productivity without breaking the bank!"
# ----------------------------------------
# Run #3 result:
# "Affordable and efficient, this wireless mouse is perfect for students on the go. With a sleek design and reliable connectivity, it enhances productivity without breaking the bank. Get ready to tackle your assignments with ease at just $29.99!"
# ----------------------------------------
# Run #4 result:
# ...
